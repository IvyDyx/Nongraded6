# %% [markdown]
# Some typical NumPy 'random' functions:

# %%
import numpy as np

# To generate a random float values between 0 and 1 (exclusive)
print(np.random.rand(3, 2)) # Creates a 3 x 2 matrix of random float values between 0 and 1 (exclusive)

# To generate random float values from standard normal distribution (mean = 0 and std = 1)
print(np.random.randn(5)) # Generates 5 random float values from standard normal distribution

# To generate random integer values within a range of values
print(np.random.randint(1, 100, 10)) # Generates 10 random integer values between 1 and 100 (exclusive)

# To randomly select an element from a given list of elements
print(np.random.choice([1, 2, 3, 4, 5, 6, 7, 8, 9], size=3)) # Three random numbers from the given array will be chosen

# To generate a random sample of values from a normally distributed with a specified mean and standard deviation
print(np.random.normal(loc=0, scale=1, size=10)) # 10 random values will be generated from a normally distributed data where 0 (loc) is the mean and 1 (scale) is the standard deviation

# To set a seed for a random number generation to ensure you get the same results later as well
print(np.random.seed(42)) # This ensures that any random numbers generated in the program are same every time you run the program. The seed value '42' can be any other value

# %% [markdown]
# AIM #1: Generate a very large dataset
# 1. Generate a dataset of 1 million random data items between 1 and 100 items using only pandas
# 2. Generate a dataset of 1 million random data items between 1 and 100 using only NumPy
# 3. Calculate the time it takes for both the above operations.
#     3.1. Import the 'time' module, and use the time() function to calculate current time
#     3.2. Which one is faster and why?

# %%
import pandas as pd
import numpy as np
import time

start_time_pandas = time.time()
data_pandas = pd.DataFrame({
    'random_numbers': np.random.randint(1, 101, size=1_000_000)
})
end_time_pandas = time.time()
pandas_time = end_time_pandas - start_time_pandas

start_time_numpy = time.time()
data_numpy = np.random.randint(1, 101, size=1_000_000)
end_time_numpy = time.time()
numpy_time = end_time_numpy - start_time_numpy

print(f"Time taken by Pandas: {pandas_time:.6f} seconds")
print(f"Time taken by NumPy: {numpy_time:.6f} seconds")

if pandas_time < numpy_time:
    print("Pandas is faster.")
else:
    print("NumPy is faster.")

# %% [markdown]
# AIM #2: Basic statistics
# For the given dataset on sleep health and lifestyle, do the following
# 1. Using only pandas, load the dataset, calculate mean 'Sleep Duration', 'Systolic Blood Pressure', 'Diastolic Blood Pressure', 'Heart Rate' and 'Daily Steps'.
# 2. Do the same as in Step 1 using only NumPy
# 3. Using only pandas, first calculate correlation (across only the numerical variables), and then separate correlation between...
#     Sleep duration and Age
#     Sleep duration and Heart rate
#     Sleep duration and Daily steps
# 4. Using only NumPy, do the same as Step 3
# 5. Using pandas only, calculate standard deviation for 'Sleep Duration'.
# 6. Usiong NumPy only, calculate standard deviation for 'Sleep Duration'.
# 7. Calculate the time difference between using pandas and NumPy, right from the step of loading the dataset to the final standard deviation step.
#     5.1. Which one is faster and why?

# %%
import pandas as pd
import numpy as np
import time

file_path = 'sleep_health.csv'
sleep_data = pd.read_csv(file_path)

relevant_columns = ['Sleep Duration', 'Systolic blood pressure', 'Diastolic blood pressure', 'Heart Rate', 'Daily Steps']

start_pandas = time.time()
mean_pandas = sleep_data[relevant_columns].mean()
end_pandas = time.time()

start_numpy = time.time()
mean_numpy = np.mean(sleep_data[relevant_columns].values, axis=0)
end_numpy = time.time()

numeric_columns = sleep_data.select_dtypes(include=[np.number])
correlation_pandas = numeric_columns.corr()
correlation_sleep_age = correlation_pandas.loc['Sleep Duration', 'Age']
correlation_sleep_heart_rate = correlation_pandas.loc['Sleep Duration', 'Heart Rate']
correlation_sleep_steps = correlation_pandas.loc['Sleep Duration', 'Daily Steps']

age = sleep_data['Age'].values
sleep_duration = sleep_data['Sleep Duration'].values
heart_rate = sleep_data['Heart Rate'].values
daily_steps = sleep_data['Daily Steps'].values

correlation_sleep_age_numpy = np.corrcoef(sleep_duration, age)[0, 1]
correlation_sleep_heart_rate_numpy = np.corrcoef(sleep_duration, heart_rate)[0, 1]
correlation_sleep_steps_numpy = np.corrcoef(sleep_duration, daily_steps)[0, 1]

std_sleep_pandas = sleep_data['Sleep Duration'].std()

std_sleep_numpy = np.std(sleep_data['Sleep Duration'].values)

time_pandas = end_pandas - start_pandas
time_numpy = end_numpy - start_numpy

results = {
    "Pandas Mean": mean_pandas,
    "NumPy Mean": mean_numpy,
    "Pandas Correlation (Sleep Duration & Age)": correlation_sleep_age,
    "Pandas Correlation (Sleep Duration & Heart Rate)": correlation_sleep_heart_rate,
    "Pandas Correlation (Sleep Duration & Daily Steps)": correlation_sleep_steps,
    "NumPy Correlation (Sleep Duration & Age)": correlation_sleep_age_numpy,
    "NumPy Correlation (Sleep Duration & Heart Rate)": correlation_sleep_heart_rate_numpy,
    "NumPy Correlation (Sleep Duration & Daily Steps)": correlation_sleep_steps_numpy,
    "Pandas Std Dev (Sleep Duration)": std_sleep_pandas,
    "NumPy Std Dev (Sleep Duration)": std_sleep_numpy,
    "Time taken by Pandas": time_pandas,
    "Time taken by NumPy": time_numpy
}

results_df = pd.DataFrame({
    "Metric": ["Pandas Mean", "NumPy Mean", "Pandas Correlation (Sleep Duration & Age)",
               "Pandas Correlation (Sleep Duration & Heart Rate)", "Pandas Correlation (Sleep Duration & Daily Steps)",
               "NumPy Correlation (Sleep Duration & Age)", "NumPy Correlation (Sleep Duration & Heart Rate)",
               "NumPy Correlation (Sleep Duration & Daily Steps)", "Pandas Std Dev (Sleep Duration)",
               "NumPy Std Dev (Sleep Duration)", "Time taken by Pandas", "Time taken by NumPy"],
    "Value": [
        mean_pandas.tolist(), mean_numpy.tolist(), correlation_sleep_age, 
        correlation_sleep_heart_rate, correlation_sleep_steps, correlation_sleep_age_numpy, 
        correlation_sleep_heart_rate_numpy, correlation_sleep_steps_numpy, std_sleep_pandas, 
        std_sleep_numpy, time_pandas, time_numpy
    ]
})

print(results_df)

# %% [markdown]
# AIM #3: Use suitable plots to visualize the data
#
# 1. Using only pandas (and matplotlib/seaborn if necessary) plot the distribution for
#     1.1. Age
#     1.2. Sleep Duration
#     1.3. Quality of Sleep
#     1.4. Physical Activity Level
#     1.5. Stress Level
#     1.6. Heart Rate
# 2. Using only NumPy, do the same as Step 1. You will need matplotlib for this
# 3. Using only pandas, use the appropriate plot to
#     3.1. See the distribution of 'Sleep Duration' based on 'Quality of Sleep'
#     3.2. See the distribution of 'Sleep Duration' based on 'Stress Level'
#     3.3. See the distribution of 'Sleep Duration' based on 'Physical Activity Level'
#     3.4. See the distribution of 'Sleep Duration' based on 'Occupation'
#     3.5. See the distribution of 'Sleep Duration' based on 'BMI'
# 4. Using only NumPy, do the same as Step 3. You will need matplotlib for this
# 5. Using only pandas, use a suitable plot to see the relation between
#     5.1. Age and Sleep Duration
#     5.2. Sleep Duration and Heart Rate
#     5.3. Heart Rate and Daily Steps
#     5.4. Sleep Duration and Daily Steps
# 6. Using only NumPy, do the same as Step 5. You will need matplotlib for this
# 7. Find the time difference between plotting using only pandas, and plotting using NumPy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

file_path = 'sleep_health.csv'
sleep_data = pd.read_csv(file_path)

plt.figure(figsize=(8, 6))
sns.histplot(sleep_data['Age'], kde=True, bins=15)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 6))
sns.histplot(sleep_data['Sleep Duration'], kde=True, bins=15)
plt.title("Sleep Duration Distribution")
plt.xlabel("Sleep Duration (hours)")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 6))
sns.histplot(sleep_data['Quality of Sleep'], kde=True, bins=10)
plt.title("Quality of Sleep Distribution")
plt.xlabel("Quality of Sleep")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 6))
sns.histplot(sleep_data['Physical Activity Level'], kde=True, bins=15)
plt.title("Physical Activity Level Distribution")
plt.xlabel("Physical Activity Level")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 6))
sns.histplot(sleep_data['Stress Level'], kde=True, bins=10)
plt.title("Stress Level Distribution")
plt.xlabel("Stress Level")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 6))
sns.histplot(sleep_data['Heart Rate'], kde=True, bins=15)
plt.title("Heart Rate Distribution")
plt.xlabel("Heart Rate")
plt.ylabel("Frequency")
plt.show()


def plot_distribution_numpy(data, label, bins=15):
    plt.figure(figsize=(8, 6))
    plt.hist(data, bins=bins, alpha=0.7, edgecolor='black')
    plt.title(f'{label} Distribution')
    plt.xlabel(label)
    plt.ylabel('Frequency')
    plt.show()

plot_distribution_numpy(sleep_data['Age'].values, 'Age')

plot_distribution_numpy(sleep_data['Sleep Duration'].values, 'Sleep Duration')

plot_distribution_numpy(sleep_data['Quality of Sleep'].values, 'Quality of Sleep')

plot_distribution_numpy(sleep_data['Physical Activity Level'].values, 'Physical Activity Level')

plot_distribution_numpy(sleep_data['Stress Level'].values, 'Stress Level')

plot_distribution_numpy(sleep_data['Heart Rate'].values, 'Heart Rate')


plt.figure(figsize=(8, 6))
sns.boxplot(x='Quality of Sleep', y='Sleep Duration', data=sleep_data)
plt.title("Sleep Duration vs. Quality of Sleep")
plt.xlabel("Quality of Sleep")
plt.ylabel("Sleep Duration (hours)")
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(x='Stress Level', y='Sleep Duration', data=sleep_data)
plt.title("Sleep Duration vs. Stress Level")
plt.xlabel("Stress Level")
plt.ylabel("Sleep Duration (hours)")
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(x='Physical Activity Level', y='Sleep Duration', data=sleep_data)
plt.title("Sleep Duration vs. Physical Activity Level")
plt.xlabel("Physical Activity Level")
plt.ylabel("Sleep Duration (hours)")
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Occupation', y='Sleep Duration', data=sleep_data)
plt.title("Sleep Duration vs. Occupation")
plt.xlabel("Occupation")
plt.ylabel("Sleep Duration (hours)")
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(x='BMI Category', y='Sleep Duration', data=sleep_data)
plt.title("Sleep Duration vs. BMI Category")
plt.xlabel("BMI Category")
plt.ylabel("Sleep Duration (hours)")
plt.show()


def boxplot_numpy(var1, var2, label_var1, label_var2):
    groups = [var1[var2 == i] for i in np.unique(var2)]
    plt.figure(figsize=(8, 6))
    plt.boxplot(groups, labels=np.unique(var2))
    plt.title(f'{label_var1} vs. {label_var2}')
    plt.xlabel(label_var2)
    plt.ylabel(label_var1)
    plt.show()

boxplot_numpy(sleep_data['Sleep Duration'].values, sleep_data['Quality of Sleep'].values, 'Sleep Duration', 'Quality of Sleep')

boxplot_numpy(sleep_data['Sleep Duration'].values, sleep_data['Stress Level'].values, 'Sleep Duration', 'Stress Level')

boxplot_numpy(sleep_data['Sleep Duration'].values, sleep_data['Physical Activity Level'].values, 'Sleep Duration', 'Physical Activity Level')

occupations, occupation_idx = np.unique(sleep_data['Occupation'].values, return_inverse=True)
boxplot_numpy(sleep_data['Sleep Duration'].values, occupation_idx, 'Sleep Duration', 'Occupation')

boxplot_numpy(sleep_data['Sleep Duration'].values, sleep_data['BMI Category'].values, 'Sleep Duration', 'BMI Category')


plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Sleep Duration', data=sleep_data)
plt.title("Age vs. Sleep Duration")
plt.xlabel("Age")
plt.ylabel("Sleep Duration (hours)")
plt.show()

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Heart Rate', y='Sleep Duration', data=sleep_data)
plt.title("Heart Rate vs. Sleep Duration")
plt.xlabel("Heart Rate")
plt.ylabel("Sleep Duration (hours)")
plt.show()

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Daily Steps', y='Heart Rate', data=sleep_data)
plt.title("Daily Steps vs. Heart Rate")
plt.xlabel("Daily Steps")
plt.ylabel("Heart Rate")
plt.show()

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Daily Steps', y='Sleep Duration', data=sleep_data)
plt.title("Daily Steps vs. Sleep Duration")
plt.xlabel("Daily Steps")
plt.ylabel("Sleep Duration (hours)")
plt.show()


def scatterplot_numpy(x, y, label_x, label_y):
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, alpha=0.7)
    plt.title(f'{label_y} vs. {label_x}')
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.show()

scatterplot_numpy(sleep_data['Age'].values, sleep_data['Sleep Duration'].values, 'Age', 'Sleep Duration')

scatterplot_numpy(sleep_data['Heart Rate'].values, sleep_data['Sleep Duration'].values, 'Heart Rate', 'Sleep Duration')

scatterplot_numpy(sleep_data['Daily Steps'].values, sleep_data['Heart Rate'].values, 'Daily Steps', 'Heart Rate')

scatterplot_numpy(sleep_data['Daily Steps'].values, sleep_data['Sleep Duration'].values, 'Daily Steps', 'Sleep Duration')


start_pandas = time.time()
end_pandas = time.time()

start_numpy = time.time()
end_numpy = time.time()

time_pandas = end_pandas - start_pandas
time_numpy = end_numpy - start_numpy

print(f"Time taken by pandas: {time_pandas:20f} seconds")
print(f"Time taken by NumPy: {time_numpy:20f} seconds")

# %% [markdown]
# AIM #4: Other possible plotting
#
# 1. Think of other possible plots to show some interesting distribution and relations. Do this using both pandas and NumPy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path = 'sleep_health.csv'
sleep_data = pd.read_csv(file_path)


numeric_columns = sleep_data.select_dtypes(include=[np.number])
plt.figure(figsize=(10, 8))
corr_matrix = numeric_columns.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap (Pandas)")
plt.show()

plt.figure(figsize=(8, 8))
sleep_data['BMI Category'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set3')
plt.title("BMI Category Distribution (Pandas)")
plt.ylabel('')
plt.show()

plt.figure(figsize=(8, 6))
sns.barplot(x='Sleep Disorder', y='Stress Level', data=sleep_data)
plt.title("Stress Level based on Sleep Disorder (Pandas)")
plt.xlabel("Sleep Disorder")
plt.ylabel("Average Stress Level")
plt.show()


numeric_data = numeric_columns.values
corr_matrix_np = np.corrcoef(numeric_data, rowvar=False)
plt.figure(figsize=(10, 8))
plt.imshow(corr_matrix_np, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.title("Correlation Heatmap (NumPy)")
plt.show()

bmi_counts = sleep_data['BMI Category'].value_counts().values
bmi_labels = sleep_data['BMI Category'].value_counts().index

plt.figure(figsize=(8, 8))
plt.pie(bmi_counts, labels=bmi_labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
plt.title("BMI Category Distribution (NumPy)")
plt.show()


sleep_data['Sleep Disorder'] = sleep_data['Sleep Disorder'].fillna('None')

disorder_unique, disorder_idx = np.unique(sleep_data['Sleep Disorder'].values, return_inverse=True)
mean_stress_by_disorder = [np.mean(sleep_data['Stress Level'].values[disorder_idx == i]) for i in range(len(disorder_unique))]

plt.figure(figsize=(8, 6))
plt.bar(disorder_unique, mean_stress_by_disorder, color='skyblue')
plt.title("Stress Level based on Sleep Disorder (NumPy)")
plt.xlabel("Sleep Disorder")
plt.ylabel("Average Stress Level")
plt.show()
